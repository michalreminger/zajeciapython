# %% [markdown]
# <a href="https://colab.research.google.com/github/michalreminger/zajeciapython/blob/main/Copy_of_hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Witaj w Google Colab!

# %%
pierwsza_zmienna = 1
druga_zmienna = 2.43
trzecia_zmienna = "hello"

# %%
# to jest komentarz

'''
to jest blok
komentarzy
mogę dodawać ich wiele w 
różnych linijkach
'''
# Out:
# '\nto jest blok\nkomentarzy\nmogę dodawać ich wiele w \nróżnych linijkach\n'

# %%
print('cokolwiek')
print(pierwsza_zmienna)
print(druga_zmienna, trzecia_zmienna)
print('wypisałem',"Michal Reminger")
# Out:
# cokolwiek
# 1
# 2.43 hello
# wypisałem Michal Reminger

# %%
wynik_dodawania = pierwsza_zmienna +druga_zmienna
 # dozwolone są oczywiście także inne operacje matematyczne
print(wynik_dodawania)
# Out:
# 3.43

# %%
# wyrażenia warunkowe

zmienna_testowa = 8
if zmienna_testowa == 8: # == oznacza porównanie, = to przypisanie!
  print('Twoja zmienna to ósemka!')
if zmienna_testowa == 8:
  print('Twoja zmienna jest mniejsza niż 8.')
if zmienna_testowa == 8:
  print('Twoja zmienna jest większa niż 8.')

### zmień kod tak, żeby zostały wypisane wszystkie 3 napisy
# Out:
# Twoja zmienna to ósemka!
# Twoja zmienna jest mniejsza niż 8.
# Twoja zmienna jest większa niż 8.

# %%
# pętla while

i = 0
while i < 6:
  print('cześć!')
  print(i)
  i = i +3 # przy każdym przejściu pętli zwiększam i
# Out:
# cześć!
# 0
# cześć!
# 3

# %%
# umieść tutaj kod, który wypisze 8 razy Twoje imię i nazwisko (while)

# %%
# pętla for

for i in range(0,10):
  print(i)
  print('hej!')
# Out:
# 0
# hej!
# 1
# hej!
# 2
# hej!
# 3
# hej!
# 4
# hej!
# 5
# hej!
# 6
# hej!
# 7
# hej!
# 8
# hej!
# 9
# hej!

# %%
# umieść tutaj kod, który wypisze 8 razy Twoje imię i nazwisko (for)

# %%
# funkcja z jednym argumentem

def moja_funkcja(a):
  b = a*a
  print(b)

# %%
moja_funkcja(10)
moja_funkcja(8)
# Out:
# 100
# 64

# %%
# funkcja z kilkoma argumentami

def moja_funkcja_2(a, b, c):
  d = a*a + b - c
  return d # zwracanie

# %%
moja_funkcja_2(1,2,3)
# Out:
# 0

# %%
# osoba

class Osoba: 
    def __init__(self, imie, nazwisko, wiek):
        self.imie = imie
        self.nazwisko = nazwisko
        self.wiek = wiek
    def przedstaw_sie(self):
        print(f"Jestem {self.imie} {self.nazwisko}. Mam {self.wiek} lat.")
    def urodziny(self):
        wiek_przed = self.wiek
        self.wiek += 1
        return wiek_przed

# %%
# tworzymy dwa obiekty klasy Osoba
Jan = Osoba("Jan", "Nowak", 48)
Adam = Osoba("Adam", "Mickiewicz", 220)

# wywołujemy metodę przedstaw_sie() na każdym z nich
Jan.przedstaw_sie()
Adam.przedstaw_sie()

wiek_Adama_przed = Adam.urodziny()
Adam.przedstaw_sie()
print(f"Wiek Adama sprzed urodzin: {wiek_Adama_przed}")

# odwołujemy się do pól, modyfikujemy je
Jan.imie = "Stanisław"
Jan.nazwisko = "Witkiewicz"
Jan.wiek = 133

Jan.przedstaw_sie()
print(Jan.imie)
# Out:
# Jestem Jan Nowak. Mam 48 lat.
# Jestem Adam Mickiewicz. Mam 220 lat.
# Jestem Adam Mickiewicz. Mam 221 lat.
# Wiek Adama sprzed urodzin: 220
# Jestem Stanisław Witkiewicz. Mam 133 lat.
# Stanisław

# %%
# moduły 1

import math
math.sqrt(15)
# Out:
# 3.872983346207417

# %%
# moduły 2

from math import sqrt
sqrt(9)
# Out:
# 3.0

# %% [markdown]
# ### Dane i analiza

# %%
# ładowanie plików z dysku komputera

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9b679331-cd2a-4f02-bd88-fc64b4a45105" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b679331-cd2a-4f02-bd88-fc64b4a45105">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Table_1.csv to Table_1.csv
# User uploaded file "Table_1.csv" with length 3117 bytes

# %%
import pandas as pd # teraz do funkcji z tego modułu możemy się odwoływać poprzez pd
import numpy as np # teraz do funkcji z tego modułu możemy się odwoływać poprzez np

# %%
pd.read_csv('Table_1.csv')
# Out:
#          Sample_name Plants? Earthworms?     Matrix?      Ade_ug/g  \
# 0          Lterr 1.1     Yes         Yes        Soil  3.647927e-02
# 1          Lterr 1.2     Yes         Yes        Soil  2.566434e-02
# 2          Lterr 1.3     Yes         Yes        Soil  1.990136e-02
# 3          Lterr 1.4     Yes         Yes        Soil  2.465555e-02
# 4          Lterr 1.5     Yes         Yes        Soil  2.819405e-02
# 5          Lterr 2.1     Yes          No        Soil  2.045743e-02
# 6          Lterr 2.2     Yes          No        Soil  1.015064e-02
# 7          Lterr 2.3     Yes          No        Soil  3.125461e-02
# 8          Lterr 2.4     Yes          No        Soil  2.580020e-02
# 9          Lterr 2.5     Yes          No        Soil  2.710730e-02
# 10         Lterr 7.1      No         Yes        Soil  1.807190e-02
# 11         Lterr 7.2      No         Yes        Soil  2.422163e-02
# 12         Lterr 7.3      No         Yes        Soil  1.877313e-02
# 13         Lterr 7.4      No         Yes        Soil  2.341737e-02
# 14         Lterr 7.5      No         Yes        Soil  5.983781e-02
# 15         Lterr 8.1      No          No        Soil  2.678673e-02
# 16         Lterr 8.2      No          No        Soil  2.411398e-02
# 17         Lterr 8.3      No          No        Soil  2.863097e-02
# 18         Lterr 8.4      No          No        Soil  2.375003e-02
# 19         Lterr 8.5      No          No        Soil  3.619383e-02
# 20      Worms only A      No         Yes  Hydroponic  7.615910e-03
# 21      Worms only B      No         Yes  Hydroponic  1.010321e-02
# 22      Worms only C      No         Yes  Hydroponic  1.649080e-02
# 23      Worms only D      No         Yes  Hydroponic  5.665084e-03
# 24     Plants only A     Yes          No  Hydroponic  2.220499e-02
# 25     Plants only B     Yes          No  Hydroponic  2.433352e-02
# 26     Plants only C     Yes          No  Hydroponic  2.625654e-02
# 27     Plants only D     Yes          No  Hydroponic  1.010876e-03
# 28  Worms & plants A     Yes         Yes  Hydroponic  4.379062e-02
# 29  Worms & plants B     Yes         Yes  Hydroponic  3.101990e-02
# 30  Worms & plants C     Yes         Yes  Hydroponic  2.187367e-02
# 31  Worms & plants D     Yes         Yes  Hydroponic  2.161321e-03
# 32           Blank A      No          No  Hydroponic  1.810000e-08
# 33           Blank B      No          No  Hydroponic  1.810000e-08
# 34           Blank C      No          No  Hydroponic  1.810000e-08
# 35           Blank D      No          No  Hydroponic  1.810000e-08
#
#    Outlier_LOD?   Zeatin_ug/g Outlier_LOD?.1       iP_ug/g Outlier_LOD?.2  \
# 0             N  6.150850e-04              N  3.590316e+00              N
# 1             N  5.922380e-04              N  4.591538e+00              N
# 2             N  4.125560e-04              N  5.846024e+00              N
# 3             N  8.687880e-04              N  1.120330e-03              N
# 4             N  1.752815e-03              N  8.660618e-03              N
# 5             N  6.376290e-04              N  7.307985e+00              N
# 6             N  4.670630e-04              N  6.032559e+00              N
# 7             N  6.107250e-04              N  9.831913e+00              N
# 8             N  8.066510e-04              N  8.252610e-04              N
# 9             N  1.193288e-03              N  1.030931e-02              N
# 10            N  5.388560e-04              N  8.639777e+00              N
# 11            N  5.398210e-04              N  9.473639e+00              N
# 12            N  5.107394e-03              N  3.481458e-01              N
# 13            N  1.439191e-03              N  2.209037e-03              N
# 14            N  1.532869e-03              N  9.163572e-03              N
# 15            N  2.279878e-03              N  3.770878e-01              N
# 16            N  6.907990e-04              N  9.202746e+00              N
# 17            N  2.318947e-03              N  2.342294e+00              N
# 18            N  1.242467e-03              N  9.922131e-03              N
# 19            N  9.527750e-04              N  4.627606e-03              N
# 20            N  6.075810e-04              N  9.872985e-03              N
# 21            N  1.045800e-04              N  9.680420e-04              N
# 22            N  6.375110e-04              N  6.018113e-03              N
# 23            N  1.120000e-06              N  1.070000e-05              N
# 24            N  3.327760e-04              N  9.320760e-04              N
# 25            N  1.585340e-04              N  1.262900e-03              N
# 26            N  3.568000e-04              N  1.626228e-03              N
# 27            Y  1.106731e-02              Y  4.570560e-04              N
# 28            N  1.908530e-04              N  4.138440e-04              N
# 29            N  1.471250e-04              N  1.054491e-03              N
# 30            N  1.813700e-04              N  6.000000e-04              N
# 31            N  7.127031e-03              Y  7.116480e-04              N
# 32          LOD  2.150000e-09            LOD  1.490000e-08            LOD
# 33          LOD  5.620000e-05              N  3.882214e-03              Y
# 34          LOD  5.000000e-05              N  1.490000e-08            LOD
# 35          LOD  4.760000e-05              N  1.490000e-08            LOD
#
#     ABA_ug/g Outlier_LOD?.3 IAA_(D/U)
# 0   0.000008            LOD         U
# 1   0.000008            LOD         U
# 2   0.000008            LOD         U
# 3   0.002900              N         U
# 4   0.000008            LOD         U
# 5   0.000008            LOD         U
# 6   0.007988              N         D
# 7   0.000008            LOD         U
# 8   0.000008            LOD         U
# 9   0.000800              N         U
# 10  0.000008            LOD         U
# 11  0.000008            LOD         U
# 12  0.000008            LOD         U
# 13  0.000008            LOD         U
# 14  0.002900              N         U
# 15  0.000008            LOD         U
# 16  0.000008            LOD         U
# 17  0.000008            LOD         U
# 18  0.000008            LOD         U
# 19  0.000008            LOD         U
# 20  0.000200              N         U
# 21  0.000008            LOD         U
# 22  0.000381              N         U
# 23  0.000084              N         D
# 24  0.000008            LOD         U
# 25  0.000891              N         U
# 26  0.000979              N         U
# 27  0.001712              N         D
# 28  0.002203              N         U
# 29  0.004074              N         U
# 30  0.001408              N         U
# 31  0.004683              N         D
# 32  0.006188              Y         U
# 33  0.001194              N         U
# 34  0.000810              N         U
# 35  0.000302              N         U

# %%
df = pd.read_csv('Table_1.csv') # zapisujemy naszą RAMKĘ DANYCH pod zmienną df

# %%
df.head(10) # wypisuje nam 10 pierwszych wierszy
# Out:
#   Sample_name Plants? Earthworms? Matrix?  Ade_ug/g Outlier_LOD?  Zeatin_ug/g  \
# 0   Lterr 1.1     Yes         Yes    Soil  0.036479            N     0.000615
# 1   Lterr 1.2     Yes         Yes    Soil  0.025664            N     0.000592
# 2   Lterr 1.3     Yes         Yes    Soil  0.019901            N     0.000413
# 3   Lterr 1.4     Yes         Yes    Soil  0.024656            N     0.000869
# 4   Lterr 1.5     Yes         Yes    Soil  0.028194            N     0.001753
# 5   Lterr 2.1     Yes          No    Soil  0.020457            N     0.000638
# 6   Lterr 2.2     Yes          No    Soil  0.010151            N     0.000467
# 7   Lterr 2.3     Yes          No    Soil  0.031255            N     0.000611
# 8   Lterr 2.4     Yes          No    Soil  0.025800            N     0.000807
# 9   Lterr 2.5     Yes          No    Soil  0.027107            N     0.001193
#
#   Outlier_LOD?.1   iP_ug/g Outlier_LOD?.2  ABA_ug/g Outlier_LOD?.3 IAA_(D/U)
# 0              N  3.590316              N  0.000008            LOD         U
# 1              N  4.591538              N  0.000008            LOD         U
# 2              N  5.846024              N  0.000008            LOD         U
# 3              N  0.001120              N  0.002900              N         U
# 4              N  0.008661              N  0.000008            LOD         U
# 5              N  7.307985              N  0.000008            LOD         U
# 6              N  6.032559              N  0.007988              N         D
# 7              N  9.831913              N  0.000008            LOD         U
# 8              N  0.000825              N  0.000008            LOD         U
# 9              N  0.010309              N  0.000800              N         U

# %% [markdown]
# ### Uruchom poniższe komórki - co się stało?

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Ade_ug/g       0.020722
# Zeatin_ug/g    0.001269
# iP_ug/g        1.879408
# ABA_ug/g       0.001107
# dtype: float64

# %%
df.describe()
# Out:
#            Ade_ug/g   Zeatin_ug/g       iP_ug/g   ABA_ug/g
# count  3.600000e+01  3.600000e+01  3.600000e+01  36.000000
# mean   2.072191e-02  1.268506e-03  1.879408e+00   0.001107
# std    1.332984e-02  2.196697e-03  3.304939e+00   0.001912
# min    1.810000e-08  2.150000e-09  1.490000e-08   0.000008
# 25%    1.013878e-02  1.884822e-04  9.053722e-04   0.000008
# 50%    2.358370e-02  6.091530e-04  5.322860e-03   0.000046
# 75%    2.686687e-02  1.205583e-03  2.654300e+00   0.001248
# max    5.983781e-02  1.106731e-02  9.831913e+00   0.007988

# %%
df.shape
# Out:
# (36, 13)

# %%
df.drop(['iP_ug/g'],axis=1).plot(figsize=(20,10))

# %%
df.corr()
# Out:
#              Ade_ug/g  Zeatin_ug/g   iP_ug/g  ABA_ug/g
# Ade_ug/g     1.000000    -0.202016  0.113046 -0.171627
# Zeatin_ug/g -0.202016     1.000000 -0.160264  0.107847
# iP_ug/g      0.113046    -0.160264  1.000000 -0.118216
# ABA_ug/g    -0.171627     0.107847 -0.118216  1.000000

# %%
df['Ade_ug/g']
# Out:
# 0     3.647927e-02
# 1     2.566434e-02
# 2     1.990136e-02
# 3     2.465555e-02
# 4     2.819405e-02
# 5     2.045743e-02
# 6     1.015064e-02
# 7     3.125461e-02
# 8     2.580020e-02
# 9     2.710730e-02
# 10    1.807190e-02
# 11    2.422163e-02
# 12    1.877313e-02
# 13    2.341737e-02
# 14    5.983781e-02
# 15    2.678673e-02
# 16    2.411398e-02
# 17    2.863097e-02
# 18    2.375003e-02
# 19    3.619383e-02
# 20    7.615910e-03
# 21    1.010321e-02
# 22    1.649080e-02
# 23    5.665084e-03
# 24    2.220499e-02
# 25    2.433352e-02
# 26    2.625654e-02
# 27    1.010876e-03
# 28    4.379062e-02
# 29    3.101990e-02
# 30    2.187367e-02
# 31    2.161321e-03
# 32    1.810000e-08
# 33    1.810000e-08
# 34    1.810000e-08
# 35    1.810000e-08
# Name: Ade_ug/g, dtype: float64

# %%
df['Zeatin_ug/g'].plot()

# %%
df['Zeatin_ug/g'] + df['Ade_ug/g']
# Out:
# 0     3.709436e-02
# 1     2.625658e-02
# 2     2.031392e-02
# 3     2.552434e-02
# 4     2.994686e-02
# 5     2.109505e-02
# 6     1.061770e-02
# 7     3.186534e-02
# 8     2.660686e-02
# 9     2.830058e-02
# 10    1.861075e-02
# 11    2.476146e-02
# 12    2.388053e-02
# 13    2.485656e-02
# 14    6.137068e-02
# 15    2.906661e-02
# 16    2.480478e-02
# 17    3.094992e-02
# 18    2.499250e-02
# 19    3.714660e-02
# 20    8.223491e-03
# 21    1.020779e-02
# 22    1.712831e-02
# 23    5.666204e-03
# 24    2.253777e-02
# 25    2.449205e-02
# 26    2.661335e-02
# 27    1.207819e-02
# 28    4.398148e-02
# 29    3.116702e-02
# 30    2.205504e-02
# 31    9.288352e-03
# 32    2.025000e-08
# 33    5.621810e-05
# 34    5.001810e-05
# 35    4.761810e-05
# dtype: float64

# %%
df[df['Zeatin_ug/g'] > ]
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 105          7.6         3.0          6.6         2.1  Iris-virginica
# 107          7.3         2.9          6.3         1.8  Iris-virginica
# 109          7.2         3.6          6.1         2.5  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 130          7.4         2.8          6.1         1.9  Iris-virginica
# 131          7.9         3.8          6.4         2.0  Iris-virginica
# 135          7.7         3.0          6.1         2.3  Iris-virginica

# %%
df[df['class'] == 'Iris-setosa']
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 0           5.1         3.5          1.4         0.2  Iris-setosa
# 1           4.9         3.0          1.4         0.2  Iris-setosa
# 2           4.7         3.2          1.3         0.2  Iris-setosa
# 3           4.6         3.1          1.5         0.2  Iris-setosa
# 4           5.0         3.6          1.4         0.2  Iris-setosa
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 6           4.6         3.4          1.4         0.3  Iris-setosa
# 7           5.0         3.4          1.5         0.2  Iris-setosa
# 8           4.4         2.9          1.4         0.2  Iris-setosa
# 9           4.9         3.1          1.5         0.1  Iris-setosa
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# 13          4.3         3.0          1.1         0.1  Iris-setosa
# 14          5.8         4.0          1.2         0.2  Iris-setosa
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 16          5.4         3.9          1.3         0.4  Iris-setosa
# 17          5.1         3.5          1.4         0.3  Iris-setosa
# 18          5.7         3.8          1.7         0.3  Iris-setosa
# 19          5.1         3.8          1.5         0.3  Iris-setosa
# 20          5.4         3.4          1.7         0.2  Iris-setosa
# 21          5.1         3.7          1.5         0.4  Iris-setosa
# 22          4.6         3.6          1.0         0.2  Iris-setosa
# 23          5.1         3.3          1.7         0.5  Iris-setosa
# 24          4.8         3.4          1.9         0.2  Iris-setosa
# 25          5.0         3.0          1.6         0.2  Iris-setosa
# 26          5.0         3.4          1.6         0.4  Iris-setosa
# 27          5.2         3.5          1.5         0.2  Iris-setosa
# 28          5.2         3.4          1.4         0.2  Iris-setosa
# 29          4.7         3.2          1.6         0.2  Iris-setosa
# 30          4.8         3.1          1.6         0.2  Iris-setosa
# 31          5.4         3.4          1.5         0.4  Iris-setosa
# 32          5.2         4.1          1.5         0.1  Iris-setosa
# 33          5.5         4.2          1.4         0.2  Iris-setosa
# 34          4.9         3.1          1.5         0.1  Iris-setosa
# 35          5.0         3.2          1.2         0.2  Iris-setosa
# 36          5.5         3.5          1.3         0.2  Iris-setosa
# 37          4.9         3.1          1.5         0.1  Iris-setosa
# 38          4.4         3.0          1.3         0.2  Iris-setosa
# 39          5.1         3.4          1.5         0.2  Iris-setosa
# 40          5.0         3.5          1.3         0.3  Iris-setosa
# 41          4.5         2.3          1.3         0.3  Iris-setosa
# 42          4.4         3.2          1.3         0.2  Iris-setosa
# 43          5.0         3.5          1.6         0.6  Iris-setosa
# 44          5.1         3.8          1.9         0.4  Iris-setosa
# 45          4.8         3.0          1.4         0.3  Iris-setosa
# 46          5.1         3.8          1.6         0.2  Iris-setosa
# 47          4.6         3.2          1.4         0.2  Iris-setosa
# 48          5.3         3.7          1.5         0.2  Iris-setosa
# 49          5.0         3.3          1.4         0.2  Iris-setosa

# %%
df[df['class'] == 'Iris-setosa'].describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count     50.00000   50.000000    50.000000    50.00000
# mean       5.00600    3.418000     1.464000     0.24400
# std        0.35249    0.381024     0.173511     0.10721
# min        4.30000    2.300000     1.000000     0.10000
# 25%        4.80000    3.125000     1.400000     0.20000
# 50%        5.00000    3.400000     1.500000     0.20000
# 75%        5.20000    3.675000     1.575000     0.30000
# max        5.80000    4.400000     1.900000     0.60000

# %%
df[df['class'] == 'Iris-setosa'].shape
# Out:
# (50, 5)
